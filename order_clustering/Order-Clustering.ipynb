# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dataset = pd.read_csv('MOCK_DATA_BATCHING.csv')
dataset.head(5)
# Out:
#    order_id  Section A  Section B  Section C  Section D  Section E  Section F  \
# 0         1          1          0          1          0          1          1
# 1         2          0          0          1          1          1          1
# 2         3          0          1          0          0          1          1
# 3         4          1          1          1          1          0          1
# 4         5          0          1          1          0          1          1
#
#    Section G  Section H  Section I  Section J  number_of_items
# 0          0          1          0          0                9
# 1          0          1          1          0               15
# 2          1          1          1          0                1
# 3          0          0          0          0               18
# 4          1          1          0          1                4

# %%
X = dataset.iloc[: , 1:11]
X.head(5)
# Out:
#    Section A  Section B  Section C  Section D  Section E  Section F  \
# 0          1          0          1          0          1          1
# 1          0          0          1          1          1          1
# 2          0          1          0          0          1          1
# 3          1          1          1          1          0          1
# 4          0          1          1          0          1          1
#
#    Section G  Section H  Section I  Section J
# 0          0          1          0          0
# 1          0          1          1          0
# 2          1          1          1          0
# 3          0          0          0          0
# 4          1          1          0          1

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

# %%
model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_

# %%
dataset['cluster'] = labels

# %%
dataset.head(5)
# Out:
#    order_id  Section A  Section B  Section C  Section D  Section E  Section F  \
# 0         1          1          0          1          0          1          1
# 1         2          0          0          1          1          1          1
# 2         3          0          1          0          0          1          1
# 3         4          1          1          1          1          0          1
# 4         5          0          1          1          0          1          1
#
#    Section G  Section H  Section I  Section J  number_of_items  cluster
# 0          0          1          0          0                9        0
# 1          0          1          1          0               15        3
# 2          1          1          1          0                1        4
# 3          0          0          0          0               18        1
# 4          1          1          0          1                4        3
